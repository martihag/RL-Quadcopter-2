# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-40.82042494   9.64285696   7.01216382   0.52620295   1.15570779   0.        ]
# [-21.54362731   1.14040465 -16.81727011]
# [ 0.09103134  0.06717842  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 50
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =   50, score =  -0.329 (best =  -0.052), noise_scale = 3.25

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
import matplotlib.pyplot as plt
#Thanks to Sander Bogdan from slack
#%matplotlib notebook

def plt_dynamic(fig, sub1, sub2, x, y1, y2, color_y1='g', color_y2='b'):
   sub1.plot(x, y1, color_y1)
   sub2.plot(x, y2, color_y2)
   fig.canvas.draw()

def plt_init():
    # create plots
    fig, sub1= plt.subplots(1,1)
    sub2 = sub1.twinx()

    # set plot boundaries
    sub1.set_xlim(0, time_limit) # this is typically time
    sub1.set_ylim(y1_lower, y1_upper) # limits to your y1
    sub2.set_xlim(0, time_limit) # time, again
    sub2.set_ylim(y2_lower, y2_upper) # limits to your y2

    # set labels and colors for the axes
    sub1.set_xlabel('time (s)', color='k') 
    sub1.set_ylabel('y1-axis label', color='g')
    sub1.tick_params(axis='x', colors='k')
    sub1.tick_params(axis='y', colors="g")

    sub2.set_ylabel('y2-axis label', color='b') 
    sub2.tick_params(axis='y', colors='b')
    
    return fig, sub1, sub2

# %%
# %autoreload 2

import csv
import numpy as np
from task import Task

import sys
import pandas as pd
from agents.agent import DDPG
from task import Task

#Plotting
y1_lower = -200
y1_upper = 0
y2_lower = 0
y2_upper = 150

# Modify the values below to give the quadcopter a different starting position.
time_limit = 5                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
#file_output = 'training_data.txt'                # file name for saved results

num_episodes = 300
target_pos = np.array([0., 0., 100.])
task = Task(init_pose, init_velocities, init_angle_velocities)
agent = DDPG(task)

all_rewards = []

ep_freq = 20

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    should_graph = i_episode % ep_freq == 0
    x, y1, y2 = [], [], []
    
    if should_graph:
        fig, sub1, sub2 = plt_init()
    
    episodic_reward = 0
    step = 0
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        
        state = next_state
        episodic_reward += reward
        step += 1
        
        x.append(task.sim.time)
        y1.append(reward)
        y2.append(task.sim.pose[2])
        
        if done:
            if should_graph:
                plt_dynamic(fig, sub1, sub2, x, y1, y2)
            
            print("\rEpisode = {:4d}, totla_reward = {:7.3f}, z = {:7.3f}".format(
                i_episode, episodic_reward, task.sim.pose[2]))  # [debug]
            all_rewards.append(episodic_reward)
            break
    #sys.stdout.flush()
# Out:
# Episode =    1, totla_reward = -42.170, z =   0.000
# Episode =    2, totla_reward = -133.006, z =   0.000
# Episode =    3, totla_reward = -100.623, z =   0.000
# Episode =    4, totla_reward = -54.651, z =   0.000
# Episode =    5, totla_reward = -12.419, z =   0.000
# Episode =    6, totla_reward = -1517.551, z =  32.709
# Episode =    7, totla_reward = -1201.341, z =  46.123
# Episode =    8, totla_reward = -855.242, z =   9.094
# Episode =    9, totla_reward = -28.487, z =   0.000
# Episode =   10, totla_reward =  -6.595, z =   0.000
# Episode =   11, totla_reward = -13.657, z =   0.000
# Episode =   12, totla_reward =  -8.356, z =   0.000
# Episode =   13, totla_reward = -11.997, z =   0.000
# Episode =   14, totla_reward = -19.093, z =   0.000
# Episode =   15, totla_reward = -17.006, z =   0.000
# Episode =   16, totla_reward = -73.236, z =   0.000
# Episode =   17, totla_reward = -47.767, z =   0.000
# Episode =   18, totla_reward = -83.555, z =   0.000
# Episode =   19, totla_reward = -57.620, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =   20, totla_reward = -31.091, z =   0.000
# Episode =   21, totla_reward = -109.011, z =   0.000
# Episode =   22, totla_reward = -19.550, z =   0.000
# Episode =   23, totla_reward = -44.984, z =   0.000
# Episode =   24, totla_reward = -73.238, z =   0.000
# Episode =   25, totla_reward = -44.967, z =   0.000
# Episode =   26, totla_reward = -37.971, z =   0.000
# Episode =   27, totla_reward = -26.740, z =   0.000
# Episode =   28, totla_reward =  -6.742, z =   0.000
# Episode =   29, totla_reward = -10.347, z =   0.000
# Episode =   30, totla_reward = -73.128, z =   0.000
# Episode =   31, totla_reward = -63.262, z =   0.000
# Episode =   32, totla_reward = -56.514, z =   0.000
# Episode =   33, totla_reward = -23.327, z =   0.000
# Episode =   34, totla_reward = -13.754, z =   0.000
# Episode =   35, totla_reward = -50.568, z =   0.000
# Episode =   36, totla_reward = -30.189, z =   0.000
# Episode =   37, totla_reward = -21.507, z =   0.000
# Episode =   38, totla_reward = -20.010, z =   0.000
# Episode =   39, totla_reward = -118.710, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =   40, totla_reward = -39.766, z =   0.000
# Episode =   41, totla_reward = -19.862, z =   0.000
# Episode =   42, totla_reward = -46.824, z =   0.000
# Episode =   43, totla_reward = -52.453, z =   0.000
# Episode =   44, totla_reward = -31.932, z =   0.000
# Episode =   45, totla_reward = -33.390, z =   0.000
# Episode =   46, totla_reward = -25.810, z =   0.000
# Episode =   47, totla_reward = -20.193, z =   0.000
# Episode =   48, totla_reward = -12.788, z =   0.000
# Episode =   49, totla_reward =  -7.063, z =   0.000
# Episode =   50, totla_reward = -21.423, z =   0.000
# Episode =   51, totla_reward = -55.179, z =   0.000
# Episode =   52, totla_reward = -75.201, z =   0.000
# Episode =   53, totla_reward = -38.105, z =   0.000
# Episode =   54, totla_reward = -144.688, z =   0.000
# Episode =   55, totla_reward = -2323.463, z =  34.194
# Episode =   56, totla_reward = -28.440, z =   0.000
# Episode =   57, totla_reward = -21.249, z =   0.000
# Episode =   58, totla_reward = -1076.114, z =   0.000
# Episode =   59, totla_reward = -53.248, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =   60, totla_reward = -61.471, z =   0.000
# Episode =   61, totla_reward = -63.797, z =   0.000
# Episode =   62, totla_reward = -46.642, z =   0.000
# Episode =   63, totla_reward = -37.464, z =   0.000
# Episode =   64, totla_reward = -15.011, z =   0.000
# Episode =   65, totla_reward = -29.147, z =   0.000
# Episode =   66, totla_reward = -30.729, z =   0.000
# Episode =   67, totla_reward =  -2.795, z =   0.000
# Episode =   68, totla_reward = -105.878, z =   0.000
# Episode =   69, totla_reward = -27.759, z =   0.000
# Episode =   70, totla_reward = -31.976, z =   0.000
# Episode =   71, totla_reward = -13.798, z =   0.000
# Episode =   72, totla_reward = -20.651, z =   0.000
# Episode =   73, totla_reward = -2352.614, z =   0.000
# Episode =   74, totla_reward = -1404.555, z =  58.914
# Episode =   75, totla_reward = -1802.955, z =  67.831
# Episode =   76, totla_reward = -48.146, z =   0.000
# Episode =   77, totla_reward = -344.001, z =   0.000
# Episode =   78, totla_reward = -3133.778, z =  36.930
# Episode =   79, totla_reward = -2554.780, z =  52.795
# <img src="data:image/png;base64,..." width="432">
# Episode =   80, totla_reward = -2669.294, z =  50.595
# Episode =   81, totla_reward = -2996.630, z =   3.306
# Episode =   82, totla_reward = -222.280, z =   0.000
# Episode =   83, totla_reward = -2361.746, z =  42.990
# Episode =   84, totla_reward = -2413.903, z =   6.904
# Episode =   85, totla_reward = -33.853, z =   0.000
# Episode =   86, totla_reward = -32.990, z =   0.000
# Episode =   87, totla_reward = -45.651, z =   0.000
# Episode =   88, totla_reward = -30.148, z =   0.000
# Episode =   89, totla_reward = -26.205, z =   0.000
# Episode =   90, totla_reward = -43.560, z =   0.000
# Episode =   91, totla_reward = -89.891, z =   0.000
# Episode =   92, totla_reward = -3377.331, z =   2.455
# Episode =   93, totla_reward = -422.510, z =   0.000
# Episode =   94, totla_reward = -21.771, z =   0.000
# Episode =   95, totla_reward = -3131.156, z =  52.669
# Episode =   96, totla_reward = -37.367, z =   0.000
# Episode =   97, totla_reward = -1111.593, z =   0.000
# Episode =   98, totla_reward = -29.814, z =   0.000
# Episode =   99, totla_reward = -53.226, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  100, totla_reward = -2794.091, z =  39.743
# Episode =  101, totla_reward = -153.263, z =   0.000
# Episode =  102, totla_reward = -3096.272, z =  37.445
# Episode =  103, totla_reward = -68.216, z =   0.000
# Episode =  104, totla_reward = -130.415, z =   0.000
# Episode =  105, totla_reward = -22.596, z =   0.000
# Episode =  106, totla_reward = -31.512, z =   0.000
# Episode =  107, totla_reward = -30.570, z =   0.000
# Episode =  108, totla_reward =  -0.327, z =   0.000
# Episode =  109, totla_reward = -21.373, z =   0.000
# Episode =  110, totla_reward = -18.339, z =   0.000
# Episode =  111, totla_reward = -38.864, z =   0.000
# Episode =  112, totla_reward = -187.554, z =   0.000
# Episode =  113, totla_reward = -47.287, z =   0.000
# Episode =  114, totla_reward = -105.432, z =   0.000
# Episode =  115, totla_reward = -87.068, z =   0.000
# Episode =  116, totla_reward = -191.120, z =   0.000
# Episode =  117, totla_reward = -59.137, z =   0.000
# Episode =  118, totla_reward = -15.341, z =   0.000
# Episode =  119, totla_reward = -1892.957, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  120, totla_reward = -315.053, z =   0.000
# Episode =  121, totla_reward =  -6.277, z =   0.000
# Episode =  122, totla_reward = -16.010, z =   0.000
# Episode =  123, totla_reward = -13.862, z =   0.000
# Episode =  124, totla_reward = -59.121, z =   0.000
# Episode =  125, totla_reward = -2402.774, z =  27.455
# Episode =  126, totla_reward = -1058.885, z =   0.000
# Episode =  127, totla_reward = -2926.918, z =  20.412
# Episode =  128, totla_reward = -2927.228, z =   7.922
# Episode =  129, totla_reward = -72.548, z =   0.000
# Episode =  130, totla_reward = -35.653, z =   0.000
# Episode =  131, totla_reward = -247.505, z =   0.000
# Episode =  132, totla_reward = -1454.661, z =   0.000
# Episode =  133, totla_reward = -213.298, z =   0.000
# Episode =  134, totla_reward = -104.150, z =   0.000
# Episode =  135, totla_reward = -206.007, z =   0.000
# Episode =  136, totla_reward = -25.672, z =   0.000
# Episode =  137, totla_reward = -22.512, z =   0.000
# Episode =  138, totla_reward = -19.771, z =   0.000
# Episode =  139, totla_reward = -23.184, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  140, totla_reward = -1159.701, z =   0.000
# Episode =  141, totla_reward =   0.277, z =   0.000
# Episode =  142, totla_reward = -111.480, z =   0.000
# Episode =  143, totla_reward = -30.630, z =   0.000
# Episode =  144, totla_reward =  -7.751, z =   0.000
# Episode =  145, totla_reward = -2292.570, z =  70.623
# Episode =  146, totla_reward = -50.898, z =   0.000
# Episode =  147, totla_reward = -348.140, z =   0.000
# Episode =  148, totla_reward = -2003.213, z =  71.308
# Episode =  149, totla_reward = -40.296, z =   0.000
# Episode =  150, totla_reward = -2775.819, z =  22.534
# Episode =  151, totla_reward = -57.846, z =   0.000
# Episode =  152, totla_reward = -133.948, z =   0.000
# Episode =  153, totla_reward = -14.913, z =   0.000
# Episode =  154, totla_reward = -54.881, z =   0.000
# Episode =  155, totla_reward = -3233.546, z =  21.092
# Episode =  156, totla_reward = -2473.570, z =  42.689
# Episode =  157, totla_reward = -17.021, z =   0.000
# Episode =  158, totla_reward = -19.619, z =   0.000
# Episode =  159, totla_reward = -2110.199, z =  62.654
# <img src="data:image/png;base64,..." width="432">
# Episode =  160, totla_reward = -28.030, z =   0.000
# Episode =  161, totla_reward = -2602.735, z =  45.785
# Episode =  162, totla_reward = -338.260, z =   0.000
# Episode =  163, totla_reward = -101.124, z =   0.000
# Episode =  164, totla_reward = -118.365, z =   0.000
# Episode =  165, totla_reward = -52.375, z =   0.000
# Episode =  166, totla_reward = -18.295, z =   0.000
# Episode =  167, totla_reward =  -5.983, z =   0.000
# Episode =  168, totla_reward = -2389.888, z =  75.349
# Episode =  169, totla_reward = -2993.959, z =  18.698
# Episode =  170, totla_reward = -40.159, z =   0.000
# Episode =  171, totla_reward = -32.699, z =   0.000
# Episode =  172, totla_reward = -14.160, z =   0.000
# Episode =  173, totla_reward = -2658.355, z =  53.700
# Episode =  174, totla_reward = -28.562, z =   0.000
# Episode =  175, totla_reward = -173.345, z =   0.000
# Episode =  176, totla_reward = -15.096, z =   0.000
# Episode =  177, totla_reward = -16.173, z =   0.000
# Episode =  178, totla_reward = -68.790, z =   0.000
# Episode =  179, totla_reward = -19.883, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  180, totla_reward = -85.668, z =   0.000
# Episode =  181, totla_reward = -102.971, z =   0.000
# Episode =  182, totla_reward = -2940.197, z =  25.740
# Episode =  183, totla_reward = -27.390, z =   0.000
# Episode =  184, totla_reward =   6.879, z =   0.000
# Episode =  185, totla_reward = -325.944, z =   0.000
# Episode =  186, totla_reward = -146.187, z =   0.000
# Episode =  187, totla_reward = -798.501, z =   0.000
# Episode =  188, totla_reward = -828.485, z =   0.000
# Episode =  189, totla_reward = -22.554, z =   0.000
# Episode =  190, totla_reward =  -7.551, z =   0.000
# Episode =  191, totla_reward = -2969.763, z =  48.376
# Episode =  192, totla_reward = -13.217, z =   0.000
# Episode =  193, totla_reward = -21.634, z =   0.000
# Episode =  194, totla_reward =   0.771, z =   0.000
# Episode =  195, totla_reward = -11.288, z =   0.000
# Episode =  196, totla_reward =   0.620, z =   0.000
# Episode =  197, totla_reward = -20.764, z =   0.000
# Episode =  198, totla_reward = -22.205, z =   0.000
# Episode =  199, totla_reward = -20.825, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  200, totla_reward = -20.799, z =   0.000
# Episode =  201, totla_reward = -17.206, z =   0.000
# Episode =  202, totla_reward =  -7.203, z =   0.000
# Episode =  203, totla_reward = -20.772, z =   0.000
# Episode =  204, totla_reward =  -1.797, z =   0.000
# Episode =  205, totla_reward = -19.017, z =   0.000
# Episode =  206, totla_reward = -19.516, z =   0.000
# Episode =  207, totla_reward =  -7.995, z =   0.000
# Episode =  208, totla_reward = -16.485, z =   0.000
# Episode =  209, totla_reward = -11.392, z =   0.000
# Episode =  210, totla_reward = -13.871, z =   0.000
# Episode =  211, totla_reward = -11.906, z =   0.000
# Episode =  212, totla_reward =  -4.291, z =   0.000
# Episode =  213, totla_reward =  -5.263, z =   0.000
# Episode =  214, totla_reward = -16.136, z =   0.000
# Episode =  215, totla_reward = -18.528, z =   0.000
# Episode =  216, totla_reward =  -8.133, z =   0.000
# Episode =  217, totla_reward = -13.523, z =   0.000
# Episode =  218, totla_reward = -14.533, z =   0.000
# Episode =  219, totla_reward =  -3.218, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  220, totla_reward =  -7.474, z =   0.000
# Episode =  221, totla_reward =   1.475, z =   0.000
# Episode =  222, totla_reward =  -7.399, z =   0.000
# Episode =  223, totla_reward = -13.737, z =   0.000
# Episode =  224, totla_reward =  -9.906, z =   0.000
# Episode =  225, totla_reward =  -7.684, z =   0.000
# Episode =  226, totla_reward =  -7.644, z =   0.000
# Episode =  227, totla_reward = -22.095, z =   0.000
# Episode =  228, totla_reward = -25.615, z =   0.000
# Episode =  229, totla_reward = -22.304, z =   0.000
# Episode =  230, totla_reward = -10.389, z =   0.000
# Episode =  231, totla_reward = -11.058, z =   0.000
# Episode =  232, totla_reward =  -6.869, z =   0.000
# Episode =  233, totla_reward =  -4.929, z =   0.000
# Episode =  234, totla_reward = -22.710, z =   0.000
# Episode =  235, totla_reward = -18.468, z =   0.000
# Episode =  236, totla_reward = -11.820, z =   0.000
# Episode =  237, totla_reward = -20.808, z =   0.000
# Episode =  238, totla_reward =  -8.218, z =   0.000
# Episode =  239, totla_reward = -32.818, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  240, totla_reward =   1.481, z =   0.000
# Episode =  241, totla_reward =  -8.260, z =   0.000
# Episode =  242, totla_reward =  -9.865, z =   0.000
# Episode =  243, totla_reward = -11.725, z =   0.000
# Episode =  244, totla_reward =  -6.237, z =   0.000
# Episode =  245, totla_reward = -19.501, z =   0.000
# Episode =  246, totla_reward =  -8.562, z =   0.000
# Episode =  247, totla_reward = -16.700, z =   0.000
# Episode =  248, totla_reward =  -1.908, z =   0.000
# Episode =  249, totla_reward =  -4.854, z =   0.000
# Episode =  250, totla_reward =   0.266, z =   0.000
# Episode =  251, totla_reward =  -6.041, z =   0.000
# Episode =  252, totla_reward =  -7.857, z =   0.000
# Episode =  253, totla_reward =  -9.665, z =   0.000
# Episode =  254, totla_reward = -26.070, z =   0.000
# Episode =  255, totla_reward = -2406.637, z =   0.000
# Episode =  256, totla_reward = -2117.725, z =  87.056
# Episode =  257, totla_reward = -26.719, z =   0.000
# Episode =  258, totla_reward = -56.985, z =   0.000
# Episode =  259, totla_reward = -3621.279, z =  16.631
# <img src="data:image/png;base64,..." width="432">
# Episode =  260, totla_reward = -182.779, z =   0.000
# Episode =  261, totla_reward = -3361.367, z =  77.864
# Episode =  262, totla_reward = -30.897, z =   0.000
# Episode =  263, totla_reward = -47.137, z =   0.000
# Episode =  264, totla_reward = -3816.767, z =  20.196
# Episode =  265, totla_reward =  -9.675, z =   0.000
# Episode =  266, totla_reward = -2751.647, z =  73.776
# Episode =  267, totla_reward = -3685.306, z =  61.683
# Episode =  268, totla_reward = -3542.977, z =  44.814
# Episode =  269, totla_reward = -316.882, z =   0.000
# Episode =  270, totla_reward = -3400.934, z =   6.315
# Episode =  271, totla_reward = -3480.369, z =  70.941
# Episode =  272, totla_reward = -2958.456, z =  15.254
# Episode =  273, totla_reward = -146.455, z =   0.000
# Episode =  274, totla_reward = -99.039, z =   0.000
# Episode =  275, totla_reward = -1575.627, z =   0.000
# Episode =  276, totla_reward = -3511.513, z =  60.114
# Episode =  277, totla_reward = -3565.141, z =  15.098
# Episode =  278, totla_reward = -2949.621, z =   0.000
# Episode =  279, totla_reward = -1501.721, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  280, totla_reward = -2505.350, z =  81.648
# Episode =  281, totla_reward = -28.118, z =   0.000
# Episode =  282, totla_reward = -739.703, z =   0.000
# Episode =  283, totla_reward = -107.670, z =   0.000
# Episode =  284, totla_reward = -233.348, z =   0.000
# Episode =  285, totla_reward = -1341.000, z =   0.000
# Episode =  286, totla_reward = -178.471, z =   0.000
# Episode =  287, totla_reward = -3653.091, z =  32.359
# Episode =  288, totla_reward = -3637.368, z =  62.081
# Episode =  289, totla_reward = -3486.696, z =  17.942
# Episode =  290, totla_reward = -2976.909, z =  78.791
# Episode =  291, totla_reward = -2782.594, z =  79.671
# Episode =  292, totla_reward = -27.110, z =   0.000
# Episode =  293, totla_reward = -1624.418, z =   0.000
# Episode =  294, totla_reward = -52.191, z =   0.000
# Episode =  295, totla_reward = -82.077, z =   0.000
# Episode =  296, totla_reward = -51.334, z =   0.000
# Episode =  297, totla_reward = -659.965, z =   0.000
# Episode =  298, totla_reward = -388.865, z =   0.000
# Episode =  299, totla_reward = -2108.354, z =   0.000
# <img src="data:image/png;base64,..." width="432">
# Episode =  300, totla_reward = -2005.873, z =  80.397
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(all_rewards)),  all_rewards, label='total_rewards')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
